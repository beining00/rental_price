# %%
import requests 
from requests_oauthlib import OAuth2

# %%
# authentication 
client_id = 'client_bf9fb97098e7fc0de63de7f8bcfb7f72'
secret = 'secret_35cbc0126b6d71f125927c942d37c763'

# %%
params = {
    "terms" :  "81 A'Beckett St, Melbourne VIC 3000", 
    "pageSize" :  20,
    "channel": "Residential"
}
url = 'https://api.domain.com.au/sandbox/v1/properties/_suggest'

# %%
requests.get(url, params)
# Out:
# <Response [401]>

# %%
# !curl -X GET "https://api.domain.com.au/sandbox/v1/properties/_suggest?terms=1%20Smith%20Street%2C%20Smithfield%2C%20NSW&pageSize=20" -H "accept: text/plain" -H "Authorization: Bearer 24f81f7749bfb4bef346b69d6c59c020"
# Out:
# [
#   {
#     "address": "1 Smith Street, Jerilderie NSW 2716",
#     "addressComponents": {
#       "unitNumber": "",
#       "streetNumber": "1",
#       "streetName": "Smith",
#       "streetType": "St",
#       "streetTypeLong": "Street",
#       "suburb": "Jerilderie",
#       "postCode": "2716",
#       "state": "NSW"
#     },
#     "id": "KP-9532-XG",
#     "relativeScore": 100
#   },
#   {
#     "address": "1 Smith Street, Tempe NSW 2044",
#     "addressComponents": {
#       "unitNumber": "",
#       "streetNumber": "1",
#       "streetName": "Smith",
#       "streetType": "St",
#       "streetTypeLong": "Street",
#       "suburb": "Tempe",
#       "postCode": "2044",
#       "state": "NSW"
#     },
#     "id": "JL-6258-HI",
#     "relativeScore": 100
#   },
#   {
#     "address": "1 Smith Street, Clunes NSW 2480",
#     "addressComponents": {
#       "unitNumber": "",
#       "streetNumber": "1",
#       "streetName": "Smith",
#       "streetType": "St",
# ...
